# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read Data

# %%
PROJECT = 'beans-tabular-IIT-G'
DATA_DIR = '/content/drive/MyDrive/W&B'

# %%
# Read csvs to DataFrame
train_df = pd.read_csv(f'{DATA_DIR}/train_c.csv')
train_df = train_df.sample(frac=1)  # shuffle the train data
train_df.reset_index(inplace=True, drop=True)

val_df = pd.read_csv(f'{DATA_DIR}/val.csv')
test_df = pd.read_csv(f'{DATA_DIR}/test_no_label.csv')

train_df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  ...  ShapeFactor4  Class    id
# 0  39768    785.134       314.380864  ...      0.991792  HOROZ  2770
# 1  59471    957.540         0.000000  ...      0.990152  HOROZ  1914
# 2  60942   1020.605       413.970269  ...      0.997805  HOROZ  6805
# 3  47142    845.750       329.745636  ...      0.977191  HOROZ  6051
# 4  56462    967.154         0.000000  ...      0.990517  HOROZ  2316
#
# [5 rows x 18 columns]

# %% [markdown]
# #EDA

# %%
train_df.describe()
# Out:
#                Area    Perimeter  ...  ShapeFactor4           id
# count    7589.00000  7589.000000  ...   7589.000000  7589.000000
# mean    42577.11912   855.427398  ...      0.995102  3794.000000
# std     43669.70026   216.996666  ...      0.004376  2190.899929
# min   -230867.00000   524.736000  ...      0.949990     0.000000
# 25%     33418.00000   703.568000  ...      0.993797  1897.000000
# 50%     42490.00000   794.308000  ...      0.996424  3794.000000
# 75%     58200.00000   975.344000  ...      0.997869  5691.000000
# max    254616.00000  1985.370000  ...      0.999733  7588.000000
#
# [8 rows x 17 columns]

# %% [markdown]
# * id column can be dropped
# * no null values.

# %%
f, ax = plt.subplots(figsize=(16, 12))
ax = sns.heatmap(train_df.drop('id',axis=1).corr(), annot=True,cmap="tab20")

# %% [markdown]
# * Most of the values are correlated to each other.
# * ShapeFactor3 and Compactness are completely correlated.
# * EquivDiameter and perimeter are completely correlated.
# * Compactness and Eccentricity are completly correlated.

# %%
train_df['Class'].value_counts()
# Out:
# DERMASON    1997
# SIRA        1462
# SEKER       1132
# HOROZ       1063
# CALI         887
# BARBUNYA     739
# BOMBAY       309
# Name: Class, dtype: int64

# %%
class_map = {
    'DERMASON':0,
    'SIRA':1,
    'SEKER':2,
    'HOROZ':3,
    'CALI':4,
    'BARBUNYA':5,
    'BOMBAY':6
}
train_df['Class'] = train_df['Class'].apply(lambda x: class_map[x])
train_df['Class'].value_counts()
# Out:
# 0    1997
# 1    1462
# 2    1132
# 3    1063
# 4     887
# 5     739
# 6     309
# Name: Class, dtype: int64

# %%
from sklearn.manifold import TSNE

# %%
X = train_df.drop(['id'],axis=1)
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df2_std = scaler.fit_transform(X)
y = train_df['Class']

# %%
tsne = TSNE(n_components=2, random_state=0,init='pca')
x_test_2d = tsne.fit_transform(df2_std)

# %%
import numpy as np
#Build the scatter plot with the two types of transactions.
color_map = {0:'red', 1:'blue',2:'green',3:'pink',4:'yellow',5:'black',6:'brown'}
plt.figure()
for idx, cl in enumerate(np.unique(y)):
    plt.scatter(x = x_test_2d[y==cl,0], 
                y = x_test_2d[y==cl,1], 
                c = color_map[idx], 
                label = cl)
plt.xlabel('X in t-SNE')
plt.ylabel('Y in t-SNE')  
plt.legend(loc='upper left')
plt.title('t-SNE visualization of test data')
plt.show()

# %% [markdown]
# * We can see few overlapping of labels
